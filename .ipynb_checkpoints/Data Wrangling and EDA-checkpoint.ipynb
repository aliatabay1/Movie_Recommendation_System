# %%
# Importing relevant libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
#Loading Dataset
m_data = pd.read_csv('/Users/Atabay/Desktop/Movie_Recommendation_System/Raw_data/movies_metadata.csv')
# Out:
# /Users/Atabay/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
m_data.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %% [markdown]
# # Wrangling Movies Data

# %% [markdown]
# ### a.Handling Missing Data

# %%
m_data.shape
# Out:
# (45466, 24)

# %%
m_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
#Checking for null values
m_data.isna().sum()
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %% [markdown]
# There are null values in most of the columns. However, belongs_to_collection, homepage and tagline consists of mostly null values. Removing those columns can help us to have a more coherent dataset.

# %%
#Removing columns
m_data.drop(["belongs_to_collection", "homepage", "tagline"], axis=1, inplace=True)

# %% [raw]
# m_data.overview

# %% [markdown]
# We cannot fill overview of movies automatically or manually therefore we can drop those rows.

# %%
drop_rows = m_data[m_data.overview.isnull()]
drop_rows = drop_rows.index
m_data.drop(drop_rows, inplace=True)

# %%
m_data.isna().sum()
# Out:
# adult                     0
# budget                    0
# genres                    0
# id                        0
# imdb_id                  15
# original_language        10
# original_title            0
# overview                  0
# popularity                5
# poster_path             346
# production_companies      3
# production_countries      3
# release_date             74
# revenue                   6
# runtime                   6
# spoken_languages          6
# status                   71
# title                     6
# video                     6
# vote_average              6
# vote_count                6
# dtype: int64

# %% [markdown]
# poster_path has 346  null values. Because we will not use it when building recommendation engine we don't need to drop the  null rows.

# %%
#Dropping rows where release date is null
drop_release = m_data[m_data.release_date.isnull()]
drop_release = drop_release.index
m_data.drop(drop_release, inplace=True)

# %%
#Dropping rows with no status
drop_status = m_data[m_data.status.isnull()]
drop_status = drop_status.index
m_data.drop(drop_status, inplace=True)

# %%
#Dropping rows with no language
drop_lang = m_data[m_data.original_language.isnull()]
drop_lang = drop_lang.index
m_data.drop(drop_lang, inplace=True)

# %%
m_data.shape
# Out:
# (44361, 21)

# %%
m_data.isna().sum()
# Out:
# adult                     0
# budget                    0
# genres                    0
# id                        0
# imdb_id                  12
# original_language         0
# original_title            0
# overview                  0
# popularity                0
# poster_path             303
# production_companies      0
# production_countries      0
# release_date              0
# revenue                   0
# runtime                   0
# spoken_languages          0
# status                    0
# title                     0
# video                     0
# vote_average              0
# vote_count                0
# dtype: int64

# %% [markdown]
# Apart from imdb_id and poster_path we don't have any columns with null values. Because imdb_id and poste_path are not important features for the recommendation system, we don't need to deal with null values.

# %% [markdown]
# ### b.Duplicate Values

# %%
m_data[m_data.duplicated(keep=False)].sort_values('id')
# Out:
#        adult  budget                                             genres  \
# 676    False       0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 1465   False       0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 24844  False       0  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 14012  False       0  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 21165  False       0  [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...
# 19890  False       0  [{'id': 14, 'name': 'Fantasy'}, {'id': 18, 'na...
# 13375  False       0  [{'id': 53, 'name': 'Thriller'}, {'id': 9648, ...
# 16764  False       0  [{'id': 53, 'name': 'Thriller'}, {'id': 9648, ...
# 13261  False       0  [{'id': 53, 'name': 'Thriller'}, {'id': 9648, ...
# 21854  False       0  [{'id': 18, 'name': 'Drama'}, {'id': 878, 'nam...
# 19925  False       0  [{'id': 18, 'name': 'Drama'}, {'id': 878, 'nam...
# 13603  False       0  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# ...

# %%
m_data = m_data.drop_duplicates()

# %%
m_data[m_data.duplicated(keep=False)].sort_values('id')
# Out:
# Empty DataFrame
# Columns: [adult, budget, genres, id, imdb_id, original_language, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, title, video, vote_average, vote_count]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# ### c.Checking Outliers

# %%
m_data.describe().T
# Out:
#                 count          mean           std  min   25%   50%    75%  \
# revenue       44348.0  1.148857e+07  6.510922e+07  0.0   0.0   0.0    0.0
# runtime       44348.0  9.506023e+01  3.749269e+01  0.0  85.0  95.0  107.0
# vote_average  44348.0  5.646435e+00  1.885414e+00  0.0   5.0   6.0    6.8
# vote_count    44348.0  1.124425e+02  4.971525e+02  0.0   3.0  10.0   35.0
#
#                        max
# revenue       2.787965e+09
# runtime       1.256000e+03
# vote_average  1.000000e+01
# vote_count    1.407500e+04

# %% [markdown]
# Most values in revenue seems to be zero. This means either revenue information is not avaliable or these movies were not shown in theaters.

# %%
m_data.hist(figsize=(15,10))
plt.subplots_adjust(hspace=0.5);

# %%
m_data[m_data.revenue != 0]
# Out:
#        adult    budget                                             genres  \
# 0      False  30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      False  65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 3      False  16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4      False         0                     [{'id': 35, 'name': 'Comedy'}]
# 5      False  60000000  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# ...      ...       ...                                                ...
# 45381  False         0  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 45401  False         0  [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 45409  False    800000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 45412  False   2000000  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
# 45422  False   5000000  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
#
#            id    imdb_id original_language               original_title  \
# ...

# %% [markdown]
# This shows that most of the movies has zero revenue. Because the revenue information is missing for most of the values, if we want to use this column in our analysis, we have to handle it accordingly.

# %% [markdown]
# # Wrangling Credits Data

# %% [markdown]
# ### a. Handling Missing Data

# %%
c_data.shape
# Out:
# (45476, 3)

# %%
c_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45476 entries, 0 to 45475
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   cast    45476 non-null  object
#  1   crew    45476 non-null  object
#  2   id      45476 non-null  int64
# dtypes: int64(1), object(2)
# memory usage: 1.0+ MB

# %% [markdown]
# There is no null value in credits data

# %% [markdown]
# ### b.Duplicate Values

# %%
c_data[c_data.duplicated(keep=False)].sort_values('id')
# Out:
#                                                     cast  \
# 25950  [{'cast_id': 12, 'character': 'The Creature', ...
# 25885  [{'cast_id': 12, 'character': 'The Creature', ...
# 9165   [{'cast_id': 11, 'character': 'Jef Costello', ...
# 7345   [{'cast_id': 11, 'character': 'Jef Costello', ...
# 25895  [{'cast_id': 11, 'character': 'Mike Gaucher / ...
# ...                                                  ...
# 25897                                                 []
# 25954  [{'cast_id': 7, 'character': 'Hollander', 'cre...
# 25887  [{'cast_id': 7, 'character': 'Hollander', 'cre...
# 24163  [{'cast_id': 2, 'character': 'Ebba', 'credit_i...
# 45275  [{'cast_id': 2, 'character': 'Ebba', 'credit_i...
#
#                                                     crew      id
# 25950  [{'credit_id': '52fe4380c3a36847f80590dd', 'de...    3057
# 25885  [{'credit_id': '52fe4380c3a36847f80590dd', 'de...    3057
# 9165   [{'credit_id': '52fe440ac3a36847f807ee01', 'de...    5511
# ...

# %%
c_data = c_data.drop_duplicates()

# %%
c_data[c_data.duplicated(keep=False)].sort_values('id')
# Out:
# Empty DataFrame
# Columns: [cast, crew, id]
# Index: []

# %%
#Save the dataset
m_data.to_csv('/Users/Atabay/Desktop/Movie_Recommendation_System/Data/m_data_wrangled.csv', index = False)

# %%
#Save the dataset
c_data.to_csv('/Users/Atabay/Desktop/Movie_Recommendation_System/Data/c_data_wrangled.csv', index = False)
